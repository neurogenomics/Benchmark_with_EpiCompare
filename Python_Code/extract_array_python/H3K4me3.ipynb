print(len(overlap))
print(overlap[3][4])
# Out:
# 29
# 90.0390724108185

# %%
replicates_sum = 0
count = 0
a = []
# K562  (0,4)(4,8)(8,12) 
# A549  (12,17)(17,21)
# H9  (21,25)(25,29)
for x in range(4):
    for y in range(4):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(4,8):
    for y in range(4,8):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(8,12):
    for y in range(8,12):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(12,17):
    for y in range(12,17):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 

print(count)
for x in range(17,21):
    for y in range(17,21):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(21,25):
    for y in range(21,25):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)


for x in range(25,29):
    for y in range(25,29):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)


replicate = (replicates_sum - len(overlap)*100)/(count - len(overlap))
print("the average replicates overlap is" + " " + str(replicate) + "%")
print(len(overlap))
print(len(a))
print(a)
# Out:
# 1499.3082699589793
# 16
# 2982.6397945053045
# 32
# 4483.982125352244
# 48
# 6790.115280276344
# 73
# 8298.720707593093
# 89
# 9735.434408914007
# 105
# 11094.612586409028
# 121
# the average replicates overlap is 89.07187593922856%
# 29
# 92
# ...

# %%
#experiment
sum_exp = 0
count = 0
a = []
# K562  (0,4)(4,8)(8,12) 
# A549  (12,17)(17,21)
# H9  (21,25)(25,29)

#K562 E1 E2
for x in range(0,4):
    for y in range(4,8):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(4,8):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

#K562 E1 E3
for x in range(0,4):
    for y in range(8,12):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(8,12):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

#K562 E2 E3

for x in range(4,8):
    for y in range(8,12):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(8,12):
    for y in range(4,8):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

#A549 E1 E2
for x in range(12,17):
    for y in range(17,21):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(17,21):
    for y in range(12,17):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

# H9 E1 E2
for x in range(21,25):
    for y in range(25,29):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(25,29):
    for y in range(21,25):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)



experiment_cor = sum_exp / count

print("the average experiments overlap is" + " " + str(experiment_cor) + "%")
print(len(a))
print(a)
# Out:
# 1376.7892277447465
# 16
# 2806.7135729367265
# 32
# 4250.411130390166
# 48
# 5524.48478664866
# 64
# 6962.788444522719
# 80
# 8145.685761251876
# 96
# 9981.329740334391
# 116
# 11622.529159818772
# 136
# 12806.816491109763
# 152
# 13972.40384979949
# 168
# the average experiments overlap is 83.16907053452077%
# 168
# ...

# %%
#cell type
# K562  (0,4)(4,8)(8,12) 
# A549  (12,17)(17,21)
# H9  (21,25)(25,29)

K562_A549 = 0
count = 0
a = []
for x in range(0,12):
    for y in range(12,21):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

for x in range(12,21):
    for y in range(0,12):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

K562_A549_a = K562_A549 / count
print("the average K562_A549 overlap is" + " " + str(K562_A549_a) + "%")

print(len(a))
print(a)
# Out:
# 8039.466293669529
# 108
# 14382.408759635151
# 216
# the average K562_A549 overlap is 66.58522573905162%
# 216
# ...

# %%
#cell type
# K562  (0,4)(4,8)(8,12) 
# A549  (12,17)(17,21)
# H9  (21,25)(25,29)

K562_H9_sum = 0
count = 0
a = []
for x in range(0,12):
    for y in range(21,29):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(21,29):
    for y in range(0,12):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print("the average K562_H9 overlap is" + " " + str(K562_H9) + "%")

print(len(a))
print(a)
# Out:
# 7274.5038662469915
# 96
# 11399.7880362689
# 192
# the average K562_H9 overlap is 59.37389602223385%
# 192
# ...

# %%
#cell type
# K562  (0,4)(4,8)(8,12) 
# A549  (12,17)(17,21)
# H9  (21,25)(25,29)

A549_H9_sum = 0
count = 0
a = []

for x in range(12,21):
    for y in range(21,29):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(21,29):
    for y in range(12,21):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print("the average A549_H9 overlap is" + " " + str(A549_H9) + "%")
print(len(a))
print(a)
# Out:
# 5218.505269844434
# 72
# 9047.040609153522
# 144
# the average A549_H9 overlap is 62.82667089689946%
# 144
# ...
