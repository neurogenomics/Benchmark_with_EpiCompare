700177160372,27.9716543404291,67.6724501560699,70.9850679114761,50.951885492534,66.055510249993,45.8170467647142,100,8.30685301313236,23.2586260228902],[33.192279905047,28.8265042832078,29.6418619052534,32.3356383527712,22.8609763649499,6.13066363917845,7.80266281349985,21.7050263185055,12.5812777376406,25.2451233357416,21.9733718650015,16.874806481577,24.2646299927753,31.9847249458148,31.241614201672,14.9860666735473,27.5776653937455,59.3353287232945,59.6656001651357,57.6839715140881,59.211476932604,64.1655485602229,59.5623903395603,100,60.9660439673857],[36.8564176939812,32.786439448876,32.5688905003626,35.4242204496012,25.1540971718637,8.77447425670776,12.4909354604786,23.7309644670051,14.3310369833212,32.2516316171139,28.3176214648296,21.8002175489485,31.0732414793329,39.4760696156635,38.7146482958666,20.1867295141407,34.4633792603336,77.6287164612038,78.8524292965917,69.3074691805656,76.8854242204496,81.5083393763597,81.6171138506164,31.2907904278463,100]]
print(overlap[2][3])
# Out:
# 81.3703268794888

# %%
#replicates
replicates_sum = 0
count = 0
a = []
#(0,4)(4,9)(9,13)(13,17)(17,21)(21,25)
for x in range(4):
    for y in range(4):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(4,9):
    for y in range(4,9):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(9,13):
    for y in range(9,13):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(13,17):
    for y in range(13,17):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 

print(count)
for x in range(17,21):
    for y in range(17,21):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(21,25):
    for y in range(21,25):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

replicate = (replicates_sum - len(overlap)*100)/(count - len(overlap))
print("the average replicates overlap is" + " " + str(replicate) + "%")
print(len(overlap))
print(len(a))
print(a)
# Out:
# 1292.4959555019184
# 16
# 2639.4163998327886
# 41
# 3824.791999406257
# 57
# 5007.040676727735
# 73
# 6226.4625350427605
# 89
# 7237.230667158109
# 105
# the average replicates overlap is 59.21538333947636%
# 25
# 80
# ...

# %%
#experiment 
#(0,4)(4,9)(9,13)(13,17)(17,21)(21,25)
sum_exp = 0
count = 0
a = []

for x in range(0,4):
    for y in range(4,9):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(4,9):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)



for x in range(9,13):
    for y in range(13,17):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(13,17):
    for y in range(9,13):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)


for x in range(17,21):
    for y in range(21,25):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(21,25):
    for y in range(17,21):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)



experiment_cor = sum_exp / count

print("the average experiments overlap is" + " " + str(experiment_cor) + "%")
print(len(a))
print(a)
# Out:
# 543.2460917647843
# 20
# 1882.8100306026968
# 40
# 2975.630147689133
# 56
# 3754.082696648327
# 72
# 4308.133136761287
# 88
# 5430.687734005248
# 104
# the average experiments overlap is 52.218151288512%
# 104
# ...

# %%
#cell type
#(0,4)(4,9)(9,13)(13,17)(17,21)(21,25)
K562_A549 = 0
count = 0
a = []
for x in range(0,9):
    for y in range(9,17):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

for x in range(9,17):
    for y in range(0,9):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

K562_A549_a = K562_A549 / count
print("the average K562_A549 overlap is" + " " + str(K562_A549_a) + "%")

print(len(a))
print(a)
# Out:
# 1250.2703514823022
# 72
# 2218.5308826163623
# 144
# the average K562_A549 overlap is 15.406464462613627%
# 144
# ...

# %%
#(0,4)(4,9)(9,13)(13,17)(17,21)(21,25)
K562_H9_sum = 0
count = 0
a = []
for x in range(0,9):
    for y in range(17,25):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(17,25):
    for y in range(0,9):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print("the average K562_H9 overlap is" + " " + str(K562_H9) + "%")

print(len(a))
print(a)
# Out:
# 412.7705986221722
# 72
# 1983.6210807341395
# 144
# the average K562_H9 overlap is 13.775146393987079%
# 144
# ...

# %%
#cell type 
A549_H9_sum = 0
count = 0
a = []

for x in range(9,17):
    for y in range(17,25):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(17,25):
    for y in range(9,17):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print("the average A549_H9 overlap is" + " " + str(A549_H9) + "%")
print(len(a))
print(a)
# Out:
# 341.68695092529737
# 64
# 2041.5889662501454
# 128
# the average A549_H9 overlap is 15.949913798829261%
# 128
# ...
