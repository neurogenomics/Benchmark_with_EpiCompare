846,95.9426630591215,75.363536929365,78.6022681480629,100,54.8661562374072,70.7270738587301,66.4245006044557,59.9608542973922,69.3753957745668],[29.2414642731433,27.8540420039892,23.3793851930072,29.3103954006805,43.3400797841136,39.6588642496773,25.5235832453362,44.8418983925848,97.2295553208964,96.645840666432,79.6359849818139,83.8070515076851,70.3640150181861,100,72.481813915288,68.2506159802886,61.7593570339082,71.1603895342016],[12.3284538870644,12.1396102488084,9.97677893466956,12.3615705167377,17.5273705001794,16.6884158817894,10.0548395617566,18.322958103521,38.9644745297636,38.9952256858888,25.4355428170424,20.2216448714562,20.1845857858694,16.5117938568652,100,81.5370847115502,62.0897381815028,84.5160043997808],[12.8587806491644,12.5415538361022,10.3213770602279,12.8764500182857,18.2734149959525,17.278177507304,10.2864492375462,19.0294996281214,40.4427204253798,40.4821683192321,27.0908411030617,21.4625306645737,21.3577471965286,17.5382870573926,92.1712367325638,100,61.8949782009295,82.2796773491015],[15.7345073562193,15.1025412394115,12.6928221132412,15.7567989300045,22.1388765046812,20.9936469014712,12.6448952296032,22.9853990191708,45.5561747659385,45.5901694159608,31.293468568881,25.7779759251003,25.7450958537673,21.2550156041016,95.5600757913509,83.7940258582256,100,94.240971912617],[12.9818178719924,12.7590143821144,10.5024367800423,13.017176743235,18.4620169040965,17.606587826324,10.629813918615,19.2914593415582,40.1404130597778,40.1872742144366,26.3896462408834,21.1880580737509,21.1365108036262,17.3501295071911,91.3255742621498,77.6591575216413,66.1121430032036,100]]
print(overlap[3][4])
print(len(overlap))
# Out:
# 50.6624342609655
# 18

# %%
replicates_sum = 0
count = 0
a = []

# K562  (0,4)(4,8) 
# A549  (8,11)(11,14)
# H9  (14,18)

for x in range(4):
    for y in range(4):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(4,8):
    for y in range(4,8):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(8,11):
    for y in range(8,11):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(11,14):
    for y in range(11,14):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 


for x in range(14,18):
    for y in range(14,18):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 


replicate = (replicates_sum - len(overlap)*100)/(count - len(overlap))
print("the average replicates overlap is" + " " + str(replicate) + "%")
print(len(overlap))
print(len(a))
print(a)
# Out:
# 1140.698069012791
# 16
# 2254.0775809285096
# 32
# 3010.4346795045662
# 41
# 3738.7214203147405
# 5111.902088239358
# the average replicates overlap is 68.99796017165329%
# 18
# 48
# ...

# %%
sum_exp = 0
count = 0
a = []
# K562  (0,4)(4,8) 
# A549  (8,11)(11,14)
# H9  (14,18)

#K562 E1 E2
for x in range(0,4):
    for y in range(4,8):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(4,8):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)



#A549 E1 E2
for x in range(8,11):
    for y in range(11,14):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(11,14):
    for y in range(8,11):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)


experiment_cor = sum_exp / count

print("the average experiments overlap is" + " " + str(experiment_cor) + "%")
print(len(a))
print(a)
# Out:
# 657.373365370288
# 16
# 1118.9124345612756
# 32
# 1493.0642096662878
# 41
# 2305.6091745464773
# 50
# the average experiments overlap is 46.112183490929546%
# 50
# ...

# %%
K562_A549 = 0
count = 0
a = []

# K562  (0,4)(4,8) 
# A549  (8,11)(11,14)
# H9  (14,18)

for x in range(0,8):
    for y in range(8,14):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

for x in range(8,14):
    for y in range(0,8):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

K562_A549_a = K562_A549 / count
print("the average K562_A549 overlap is" + " " + str(K562_A549_a) + "%")

print(len(a))
print(a)
# Out:
# 2763.2901116960275
# 48
# 4178.761828384917
# 96
# the average K562_A549 overlap is 43.52876904567622%
# 96
# ...

# %%
# K562  (0,4)(4,8) 
# A549  (8,11)(11,14)
# H9  (14,18)

K562_H9_sum = 0
count = 0
a = []
for x in range(0,8):
    for y in range(14,18):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(14,18):
    for y in range(0,8):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print("the average K562_H9 overlap is" + " " + str(K562_H9) + "%")

print(len(a))
print(a)
# Out:
# 2016.374374808853
# 32
# 2492.539886437864
# 64
# the average K562_H9 overlap is 38.945935725591625%
# 64
# ...

# %%
# K562  (0,4)(4,8) 
# A549  (8,11)(11,14)
# H9  (14,18)

A549_H9_sum = 0
count = 0
a = []

for x in range(8,14):
    for y in range(14,18):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(14,18):
    for y in range(8,14):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print("the average A549_H9 overlap is" + " " + str(A549_H9) + "%")
print(len(a))
print(a)
# Out:
# 1481.9064113880597
# 24
# 2172.203905734529
# 48
# the average A549_H9 overlap is 45.254248036136026%
# 48
# [56.8667808496093, 52.6870970824543, 45.4347650306162, 55.1503612934526, 56.5772885629465, 52.3621033225339, 44.9294419064919, 54.8340088655126, 67.6614756601257, 64.0020571171432, 57.4883885380004, 66.2456005014223, 71.0520271674341, 66.7439545896996, 60.0406855292947, 69.6903743724913, 70.7270738587301, 66.4245006044557, 59.9608542973922, 69.3753957745668, 72.481813915288, 68.2506159802886, 61.7593570339082, 71.1603895342016, 38.9644745297636, 38.9952256858888, 25.4355428170424, 20.2216448714562, 20.1845857858694, 16.5117938568652, 40.4427204253798, 40.4821683192321, 27.0908411030617, 21.4625306645737, 21.3577471965286, 17.5382870573926, 45.5561747659385, 45.5901694159608, 31.293468568881, 25.7779759251003, 25.7450958537673, 21.2550156041016, 40.1404130597778, 40.1872742144366, 26.3896462408834, 21.1880580737509, 21.1365108036262, 17.3501295071911]
