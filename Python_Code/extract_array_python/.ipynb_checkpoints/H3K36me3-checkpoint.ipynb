print(overlap[3][4])
print(len(overlap))
# Out:
# 29.6853436378692
# 15

# %%
replicates_sum = 0
count = 0
a = []
# K562  (0,4)(4,8) 
# A549  (8,12)
# H9  (12,15)
for x in range(4):
    for y in range(4):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(4,8):
    for y in range(4,8):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(8,12):
    for y in range(8,12):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(12,15):
    for y in range(12,15):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 


replicate = (replicates_sum - len(overlap)*100)/(count - len(overlap))
print("the average replicates overlap is" + " " + str(replicate) + "%")
print(len(overlap))
print(len(a))
print(a)
# Out:
# 1189.2932251759398
# 16
# 2580.9407561376497
# 32
# 4008.950894227194
# 48
# 4685.384240462509
# the average replicates overlap is 75.84248191577403%
# 15
# 42
# [48.1580760006307, 71.6844123187744, 65.4719126299803, 80.4890585045552, 60.2212713465171, 77.9409686082521, 81.6046482877982, 41.1907909126354, 57.1678537805377, 83.7523089662201, 59.2677126902907, 62.344211129748, 78.9475060127575, 73.1674160828192, 83.8675101955453, 94.6039647968708, 73.9058286662518, 86.3869380982013, 90.9046505051544, 77.7552122162523, 88.3724517339777, 90.6217338493263, 77.057145278382, 76.0571735261716, 93.7840148466334, 63.0648289092312, 79.3773588840002, 96.3134931753592, 63.6232638193972, 79.3839811071529, 97.1947903248891, 94.9735222556176, 97.695720624016, 95.2651467754448, 91.3311143922521, 76.0029029755499, 92.2052072297666, 26.0361488330283, 82.520781846776, 22.963940687486, 78.2742978476981, 74.4329697905607]

# %%
sum_exp = 0
count = 0
a = []
# K562  (0,4)(4,8) 
# A549  (8,12)
# H9  (12,15)

#K562 E1 E2
for x in range(0,4):
    for y in range(4,8):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(4,8):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)


experiment_cor = sum_exp / count

print("the average experiments overlap is" + " " + str(experiment_cor) + "%")
print(len(a))
print(a)
# Out:
# 494.17752144804695
# 16
# 1565.2624926386368
# 32
# the average experiments overlap is 48.9144528949574%
# 32
# [31.3081436360468, 29.1438103220774, 25.0433613556959, 29.7877990688719, 35.7503565783894, 35.2337997764157, 29.0428279557457, 33.8036313172198, 36.6328442233993, 33.7685555883108, 29.4588092090874, 34.9040006846905, 29.6853436378692, 28.7882969914436, 23.8327777659823, 27.9931633368012, 72.9478197218446, 54.0233190421416, 74.6130921259019, 61.053016835721, 79.4589148665066, 60.6483539277565, 80.5375292618603, 67.9378907754763, 70.7370369418237, 54.2276151057868, 72.3386205300908, 60.8036196303247, 72.9188441004491, 53.5323860907884, 74.6758566142199, 60.6310556198977]

# %%
K562_A549 = 0
count = 0
a = []

# K562  (0,4)(4,8) 
# A549  (8,12)
# H9  (12,15)

for x in range(0,8):
    for y in range(8,12):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

for x in range(8,12):
    for y in range(0,8):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

K562_A549_a = K562_A549 / count
print("the average K562_A549 overlap is" + " " + str(K562_A549_a) + "%")

print(len(a))
print(a)
# Out:
# 1375.4018322631957
# 32
# 2725.7137478908867
# 64
# the average K562_A549 overlap is 42.589277310795104%
# 64
# ...

# %%
# K562  (0,4)(4,8) 
# A549  (8,12)
# H9  (12,15)

K562_H9_sum = 0
count = 0
a = []
for x in range(0,8):
    for y in range(12,15):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(12,15):
    for y in range(0,8):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print("the average K562_H9 overlap is" + " " + str(K562_H9) + "%")

print(len(a))
print(a)
# Out:
# 514.3329155046254
# 24
# 2059.0344091409415
# 48
# the average K562_H9 overlap is 42.89655019043628%
# 48
# [13.5395314483938, 14.2914049079245, 5.9402982597366, 19.9015715148478, 20.7419400434319, 9.06287344358352, 15.637570489839, 16.4820221193073, 6.7965042745609, 15.8517165969553, 16.6150024416654, 7.06172105564874, 33.111994144097, 34.4818571577957, 14.9325525462721, 36.9425430408629, 38.4271194476546, 16.7303760334252, 37.3788529268105, 38.653949973007, 15.5788066531273, 34.4538289878817, 35.8662184684048, 15.8526595293918, 69.0808693698032, 61.892837651289, 68.1980159876722, 66.1722687726733, 67.4243153873319, 66.4868856143054, 60.2330732928826, 65.7677614048605, 66.4569759604583, 58.9727027634239, 65.6088519433835, 63.3228487980229, 64.9629296787239, 63.783419456302, 57.4000224668614, 63.3986744551786, 67.9471093523791, 62.5808319660264, 67.5610462310588, 65.6693369365891, 64.5207991506611, 63.8451886883505, 59.810829070553, 63.6038992375253]

# %%
# K562  (0,4)(4,8) 
# A549  (8,12)
# H9  (12,15)

A549_H9_sum = 0
count = 0
a = []

for x in range(8,12):
    for y in range(12,15):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(12,15):
    for y in range(8,12):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print("the average A549_H9 overlap is" + " " + str(A549_H9) + "%")
print(len(a))
print(a)
# Out:
# 304.0057976051512
# 12
# 1185.514637445259
# 24
# the average A549_H9 overlap is 49.39644322688579%
# 24
# [26.757303417645, 28.0334466292721, 12.7322392977042, 26.7381819637353, 28.0010407076812, 12.3884241284073, 35.5288392729354, 36.9972806640905, 16.9171318162301, 31.6999924923046, 33.1289571811106, 15.0829600340349, 76.9462904106071, 76.3106359754727, 73.5978683103791, 76.3716331182382, 74.7444394518086, 74.0170748146484, 71.0233655358346, 74.1041339024938, 72.1262426406717, 71.6340121609883, 69.2790271209343, 71.3541163980311]
