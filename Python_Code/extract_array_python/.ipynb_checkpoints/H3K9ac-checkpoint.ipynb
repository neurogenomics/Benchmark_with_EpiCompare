.7026120498092,17.8642404930611,20.6087795061004,13.7855855100415,21.9898536748983,27.0848182466144,26.3569661649407,9.80084692465725,20.3798582868643,40.618003438011,32.4095425768312,12.7181250262044,34.793509706092,50.3685380067922,100,5.46643746593434,29.6482327784999],[7.04553007643735,6.99567962778332,4.44499833831838,6.7048853439681,14.7806580259222,15.6530408773679,12.3213692256564,4.74410103024261,15.1046859421735,23.620804253905,18.2369557992689,21.6018610834164,13.6174808906613,22.7982718511133,28.2319707544035,27.3762047191758,10.0531738118976,21.5852442671984,42.2648720505151,31.613492854769,14.7474243934862,37.8198737121967,76.4955134596211,53.5061482220007,100,76.8693918245264],[8.39832750234662,8.29251642631624,5.45439030634013,7.65935660039252,14.9876269306255,15.7931564126632,12.1989930881475,4.97994709446199,14.9586142162301,23.240890860995,18.4230736410957,21.1332024916802,13.9124498677362,22.5343459339534,27.423841624712,26.6217254031914,10.0895980885741,20.8277156753989,41.3260517108968,31.4258895810223,14.4500383991808,36.5440737264272,65.450977045823,58.919703046335,15.6412663196518,100]]
print(len(overlap))
print(overlap[3][4])
# Out:
# 26
# 45.1253061180456

# %%
replicates_sum = 0
count = 0
a = []
# K562  (0,4)(4,9) 
# A549  (9,14)(14,18)
# H9  (18,22)(22,26)
for x in range(4):
    for y in range(4):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(4,9):
    for y in range(4,9):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(9,14):
    for y in range(9,14):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(14,18):
    for y in range(14,18):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 

print(count)
for x in range(18,22):
    for y in range(18,22):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)

for x in range(22,26):
    for y in range(22,26):
        replicates_sum += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            a.append(overlap[x][y])
print(replicates_sum) 
print(count)


replicate = (replicates_sum - len(overlap)*100)/(count - len(overlap))
print("the average replicates overlap is" + " " + str(replicate) + "%")
print(len(overlap))
print(len(a))
print(a)
# Out:
# 1214.3602795850006
# 16
# 3028.406365498942
# 41
# 5141.649488843027
# 66
# 6425.129769928224
# 82
# 7487.915351843779
# 98
# 8461.138845102176
# 114
# the average replicates overlap is 66.60385051252473%
# 26
# 88
# ...

# %%
sum_exp = 0
count = 0
a = []
# K562  (0,4)(4,9) 
# A549  (9,14)(14,18)
# H9  (18,22)(22,26)

#K562 E1 E2
for x in range(0,4):
    for y in range(4,9):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(4,9):
    for y in range(0,4):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

#A549 E1 E2
for x in range(9,14):
    for y in range(14,18):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(14,18):
    for y in range(9,14):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

# H9 E1 E2
for x in range(22,26):
    for y in range(18,22):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(18,22):
    for y in range(22,26):
        sum_exp += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(sum_exp) 
print(count)



experiment_cor = sum_exp / count

print("the average experiments overlap is" + " " + str(experiment_cor) + "%")
print(len(a))
print(a)
# Out:
# 702.0073527324794
# 20
# 1542.6385137823659
# 40
# 2996.3601266429378
# 60
# 4454.7501460957155
# 80
# 4970.75444699708
# 96
# 5437.179022159823
# 112
# the average experiments overlap is 48.54624126928413%
# 112
# ...

# %%
K562_A549 = 0
count = 0
a = []
# K562  (0,4)(4,9) 
# A549  (9,14)(14,18)
# H9  (18,22)(22,26)

for x in range(0,9):
    for y in range(9,18):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

for x in range(9,18):
    for y in range(0,9):
        K562_A549 += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_A549) 
print(count)

K562_A549_a = K562_A549 / count
print("the average K562_A549 overlap is" + " " + str(K562_A549_a) + "%")

print(len(a))
print(a)
# Out:
# 2541.4997648274543
# 81
# 4474.444071601478
# 162
# the average K562_A549 overlap is 27.620025133342455%
# 162
# ...

# %%
# K562  (0,4)(4,9) 
# A549  (9,14)(14,18)
# H9  (18,22)(22,26)
K562_H9_sum = 0
count = 0
a = []
for x in range(0,9):
    for y in range(18,26):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(18,26):
    for y in range(0,9):
        K562_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print("the average K562_H9 overlap is" + " " + str(K562_H9) + "%")

print(len(a))
print(a)
# Out:
# 789.9379152214809
# 72
# 1894.3430389841276
# 144
# the average K562_H9 overlap is 13.15515999294533%
# 144
# ...

# %%
# K562  (0,4)(4,9) 
# A549  (9,14)(14,18)
# H9  (18,22)(22,26)
A549_H9_sum = 0
count = 0
a = []

for x in range(9,18):
    for y in range(18,26):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(18,26):
    for y in range(9,18):
        A549_H9_sum += overlap[x][y]
        count += 1
        a.append(overlap[x][y])
print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print("the average A549_H9 overlap is" + " " + str(A549_H9) + "%")
print(len(a))
print(a)
# Out:
# 949.5932866196015
# 72
# 2695.3030229586902
# 144
# the average A549_H9 overlap is 18.717382103879793%
# 144
# ...
