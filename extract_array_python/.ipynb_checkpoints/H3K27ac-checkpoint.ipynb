205023129814,7.08816878450819],[13.5913385562019,13.4023738273763,10.910191318382,12.7742846575435,18.1661679163444,15.160216536095,16.827275478296,16.4406038801654,17.1581318718268,16.4896943613194,14.5805453750714,83.3489122759826,53.1273326384452,100,9.57936854846844,6.9009112000269],[33.557239637157,33.0749799058445,30.5775634401194,32.6386496727523,41.2217246526582,37.9033184062464,39.6716040877253,39.0515558617522,40.1251578826501,39.2697209782983,36.8124928235159,87.6507061660351,79.4293259846136,85.4173843150764,100,57.4463198989551],[38.8494021239234,38.4313069654653,35.8809264988711,37.896145162639,46.5841625553976,43.3564679321013,45.154277113471,44.5940296011372,45.513838949745,44.8866962120579,42.4450204866628,88.0341165649302,80.6756417760682,85.8182122251024,83.669203110628,100]]

len(overlap)


#print(overlap[0])
#replicates
sum_overlap = 0
count = 0
record = []
for x in range(4):
    for y in range(4):
        sum_overlap += overlap[x][y]
        count += 1
        record.append(overlap[x][y])
print(sum_overlap) 
print(count)
for x in range(4,9):
    for y in range(4,9):
        sum_overlap += overlap[x][y]
        count += 1
        record.append(overlap[x][y])
print(sum_overlap) 
print(count)
for x in range(9,11):
    for y in range(9,11):
        sum_overlap += overlap[x][y]
        count += 1
        record.append(overlap[x][y])
print(sum_overlap) 
print(count)
for x in range(11,14):
    for y in range(11,14):
        sum_overlap += overlap[x][y]
        count += 1
        record.append(overlap[x][y])
print(sum_overlap) 
print(count)

for x in range(14,16):
    for y in range(14,16):
        sum_overlap += overlap[x][y]
        count += 1
        record.append(overlap[x][y])
print(sum_overlap) 
print(count)

print(len(record))
print(record)


record_r = []
for i in record:
    if i != 100:
        record_r.append(i)
print(len(record_r))
print(record_r)
# Out:
# 1350.4225484746105
# 16
# 3532.053121331525
# 41
# 3898.366523762018
# 45
# 4592.628730869741
# 54
# 4933.744253879324
# 58
# 58
# [100, 85.5618097890657, 61.8312136026333, 77.7009524180511, 85.3774997504409, 100, 57.8278374871061, 72.9294912321565, 92.8650036683786, 84.35960591133, 100, 91.8666806414422, 89.242332729347, 81.2406326197347, 69.6194886249245, 100, 100, 62.4546114742193, 77.4503201954182, 67.1974648445237, 80.0422525912722, 98.3793702603076, 100, 92.1566717006869, 85.3899741803478, 97.1825725467271, 97.1222362660512, 75.911780330091, 100, 77.9047828396622, 90.3683757395908, 96.4416746243152, 78.296560620529, 86.6261245413882, 100, 89.5160074383073, 96.682615629984, 74.0622009569378, 84.9920255183413, 73.4529505582137, 100, 100, 69.5174792814774, 96.7959231490159, 100, 100, 59.6774120451569, 59.9960118375911, 83.3958928796905, 100, 54.7166454308574, 83.3489122759826, 53.1273326384452, 100, 100, 57.4463198989551, 83.669203110628, 100]
# 42
# ...

# %%
replicates_cor = (sum_overlap - 16*100)/(count - 16)
print(replicates_cor)
# Out:
# 79.37486318760295

# %%
#experiment 
sum_exp = 0
count = 0
record_e = []
for x in range(4,9):
    for y in range(9,11):
        sum_exp += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            record_e.append(overlap[x][y])
print(sum_exp) 
print(count)

for x in range(9,11):
    for y in range(4,9):
        sum_exp += overlap[x][y]
        count += 1
        if overlap[x][y] != 100:
            record_e.append(overlap[x][y])
print(sum_exp) 
print(count)

experiment_cor = sum_exp / count

print(experiment_cor)

print(len(record_e))
print(record_e)
# Out:
# 579.2081365049913
# 10
# 1461.504385844154
# 20
# 73.0752192922077
# 20
# [55.1356704297881, 42.8863801412821, 70.4405579643072, 58.2371185917734, 65.8295323404957, 52.1203128720851, 68.0052269186309, 55.7973563853847, 61.993620414673, 48.762360446571, 90.5199612973792, 79.2583399941105, 84.4432291447562, 83.8711034453746, 86.6854570695385, 95.2114573570759, 87.2481255857545, 90.0626757263355, 92.7542174320525, 92.2416822867854]

# %%
#cell type 

K562_A549 = 0
count = 0
record_K562_A549 = []
for x in range(4,11):
    for y in range(0,4):
        K562_A549 += overlap[x][y]
        count += 1
        record_K562_A549.append(overlap[x][y])
print(K562_A549) 
print(count)


for x in range(0,4):
    for y in range(4,11):
        K562_A549 += overlap[x][y]
        count += 1
        record_K562_A549.append(overlap[x][y])
print(K562_A549) 
print(count)
K562_A549_a = K562_A549 / count
print(K562_A549_a)

print(len(record_K562_A549))
print(record_K562_A549)
# Out:
# 853.4014904375139
# 28
# 2151.9410127855735
# 56
# 38.42751808545667
# 56
# ...

# %%
#cell type 
K562_H9_sum = 0
count = 0
record_K562_A549 = []
for x in range(11,16):
    for y in range(0,4):
        K562_H9_sum += overlap[x][y]
        count += 1
        record_K562_A549.append(overlap[x][y])
print(K562_H9_sum) 
print(count)
for x in range(0,4):
    for y in range(11,16):
        K562_H9_sum += overlap[x][y]
        count += 1
        record_K562_A549.append(overlap[x][y])
print(K562_H9_sum) 
print(count)

K562_H9 = K562_H9_sum / count
print(K562_H9)
print(len(record_K562_A549))
print(record_K562_A549)
# Out:
# 421.17545242360717
# 20
# 928.6394759251294
# 40
# 23.215986898128236
# 40
# [11.7215718798294, 11.4772969322873, 9.22398517128704, 10.9493186133884, 12.4493497250824, 12.116464065567, 9.92917570623414, 11.7238885636558, 13.5913385562019, 13.4023738273763, 10.910191318382, 12.7742846575435, 33.557239637157, 33.0749799058445, 30.5775634401194, 32.6386496727523, 38.8494021239234, 38.4313069654653, 35.8809264988711, 37.896145162639, 39.0569308376994, 30.8045887462751, 34.4039109518337, 10.217556434178, 8.43931986833648, 36.4323029314877, 28.2417728679333, 32.0849831963531, 9.17712042059029, 7.54833128140285, 43.1479928728645, 34.1054396813751, 39.2123467141809, 13.1747196310659, 11.0339587045383, 40.7892087779344, 32.4788045545042, 36.3510278952196, 11.3482316623045, 9.41547547144487]

# %%
#cell type 
A549_H9_sum = 0
count = 0
record_A549_H9 = []

for x in range(4,11):
    for y in range(11,16):
        A549_H9_sum += overlap[x][y]
        count += 1
        record_A549_H9.append(overlap[x][y])
print(A549_H9_sum) 
print(count)

for x in range(11,16):
    for y in range(4,11):
        A549_H9_sum += overlap[x][y]
        count += 1
        record_A549_H9.append(overlap[x][y])

print(A549_H9_sum) 
print(count)
A549_H9 = A549_H9_sum / count
print(A549_H9)
print(len(record_A549_H9))
print(record_A549_H9)
# Out:
# 835.9393200402936
# 35
# 1744.9809867126703
# 70
# 24.928299810181006
# 70
# ...
